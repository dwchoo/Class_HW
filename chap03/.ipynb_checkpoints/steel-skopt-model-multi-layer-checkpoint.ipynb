# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split

import numpy as np
import csv
import time
import math
from multiprocessing import Process, Manager

import skopt
from skopt import gp_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence, plot_objective, plot_evaluations

# %%
def loss_min_max(loss):
    if math.isnan(loss):
        loss = 1e+5
    else:
        loss = min(float(loss), 1e+5)
        loss = max(float(loss), 1e-10)
    return loss

# %%
def load_steal_dataset():
    with open('../../data/chap03/faults.csv') as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader, None)
        rows = []
        for row in csvreader:
            rows.append(row)

    global data, input_cnt, output_cnt
    input_cnt, output_cnt = 27, 7
    data = np.asarray(rows, dtype='float32')
    x = data[:,:input_cnt]
    y = data[:,-output_cnt:]
    return data,x,y
    
def kfold_data(data):
    import sklearn
    from sklearn.model_selection import KFold
    kf = KFold(n_splits=10, shuffle=True)
    kf.get_n_splits(data)
    kfold_data = {}
    for index, (train_index, test_index) in enumerate(kf.split(data)):
        train_data = data[train_index]
        test_data = data[test_index]
        kfold_data[index] = {'train' : train_data, 'test' : test_data}
    return kfold_data

def kfold_return_train(n_fold, kfold_data):
    output_cnt = 7
    if n_fold not in range(10):
        print('{} is not in range(10)'.format(n_fold))
        raise NameError('Change n_fold')
    train_data = kfold_data[n_fold]['train']
    #test_data = kfold_data[n_fold]['test']
    train_data_input = train_data[:, :-output_cnt]
    train_data_output = train_data[:, -output_cnt:]
    return [train_data_input, train_data_output]
def kfold_return_test(n_fold, kfold_data):
    output_cnt = 7
    if n_fold not in range(10):
        print('{} is not in range(10)'.format(n_fold))
        raise NameError('Change n_fold')
    #train_data = kfold_data[n_fold]['train']
    test_data = kfold_data[n_fold]['test']
    test_data_input = test_data[:, :-output_cnt]
    test_data_output = test_data[:, -output_cnt:]
    return [test_data_input, test_data_output]

# %% [markdown]
# ## Categorycal Cross-entropy
# $L(y,\hat{y}) = - \sum_{j=0}^M \sum_{i=0}^N (y_{i,j}*\log(\hat{y}_{i,j}))$

# %%
class steel_model:
    def __init__(self,learning_rate = 0.001,n_fold = None):
        self.learning_rate = learning_rate
        self.input_shape = 27 #input_cnt
        self.output_shape = 7 #output_cnt
        
        self.model = self.define_model()
        
        
    def init_data(self, train_data, test_data):
        self.X_train = train_data[0]
        self.Y_train = train_data[1]
        self.X_test = test_data[0]
        self.Y_test = test_data[1]
        
    def define_model(self,verbose = 0):
        x = Input(shape=(self.input_shape))
        y = Dense(self.output_shape, activation='softmax')(x)
        __model = Model(x, y)
        if verbose is not 0: __model.summary()
        return __model
    
    def model_compile(self):
        optimizer = tf.keras.optimizers.SGD(learning_rate=self.learning_rate)
        self.model.compile(optimizer=optimizer,
                           loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=['accuracy']
                          )
    
    def model_fit(self,verbose = 0):
        self.model.fit(x = self.X_train, y = self.Y_train,
                       #validation_split=0.05,
                       #shuffle=True,
                       validation_data = (self.X_test, self.Y_test),
                       batch_size = 64,
                       epochs = 30,
                       verbose = verbose
                      )
        
    def model_evaluate(self,verbose=0):
        output = self.model.predict(self.X_test,verbose=verbose)
        test_loss, test_acc = self.model.evaluate(self.X_test, self.Y_test,verbose=verbose)
        
        if verbose is not 0:
            print("acc: {:2.4f}, loss: {:2.4f}".format(test_acc, test_loss))
        
        result_dict = {'acc' : test_acc, 'loss' : test_loss}

        return result_dict

# %%
class steel_model_3_layer(steel_model):
    def __init__(self,HP = [None, None, None],learning_rate = 0.001,n_fold = None):
        self.layer_1_unit = HP[0]
        self.layer_2_unit = HP[1]
        self.layer_3_unit = HP[2]
        super().__init__(learning_rate, n_fold)
        
        
    def define_model(self,verbose = 0):
        x = Input(shape=(self.input_shape))
        layer = Dense(self.layer_1_unit, activation='relu')(x)
        layer = Dense(self.layer_2_unit, activation='relu')(layer)
        layer = Dense(self.layer_3_unit, activation='relu')(layer)
        y = Dense(self.output_shape, activation='softmax')(layer)
        __model = Model(x, y)
        if verbose is not 0: __model.summary()
        return __model
    
    def model_compile(self):
        optimizer = tf.keras.optimizers.SGD(learning_rate=self.learning_rate)
        self.model.compile(optimizer=optimizer,
                           loss=tf.keras.losses.CategoricalCrossentropy(),
                           metrics=['accuracy']
                          )
    
    def model_fit(self,verbose = 0):
        self.model.fit(x = self.X_train, y = self.Y_train,
                       #validation_split=0.05,
                       #shuffle=True,
                       validation_data = (self.X_test, self.Y_test),
                       batch_size = 64,
                       epochs = 30,
                       verbose = verbose
                      )
        
    def model_evaluate(self,verbose=0):
        output = self.model.predict(self.X_test,verbose=verbose)
        test_loss, test_acc = self.model.evaluate(self.X_test, self.Y_test,verbose=verbose)
        test_loss = loss_min_max(test_loss)
        
        if verbose is not 0:
            print("acc: {:2.4f}, loss: {:2.4f}".format(test_acc, test_loss))
        
        result_dict = {'acc' : test_acc, 'loss' : test_loss}

        return result_dict

# %%
class steel_model_4_layer(steel_model):
    def __init__(self,HP = [None, None, None],learning_rate = 0.001,n_fold = None):
        self.layer_1_unit = HP[0]
        self.layer_2_unit = HP[1]
        self.layer_3_unit = HP[2]
        self.layer_4_unit = HP[3]
        super().__init__(learning_rate, n_fold)
        
        
    def define_model(self,verbose = 0):
        x = Input(shape=(self.input_shape))
        layer = Dense(self.layer_1_unit, activation='relu')(x)
        layer = Dense(self.layer_2_unit, activation='relu')(layer)
        layer = Dense(self.layer_3_unit, activation='relu')(layer)
        layer = Dense(self.layer_4_unit, activation='relu')(layer)
        y = Dense(self.output_shape, activation='softmax')(layer)
        __model = Model(x, y)
        if verbose is not 0: __model.summary()
        return __model

# %% [raw]
# data, x,y = load_steal_dataset()
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %% [raw]
# model = steel_model_3_layer(HP=[20,20,10])
# model.init_data(
#     train_data=[x_train, y_train],
#     test_data=[x_test, y_test]
# )
# model.model_compile()
# model.model_fit(verbose=1)

# %%
class steal_model_optimize:
    def __init__(self,learning_rate = 0.01):
        self.input_cnt, self.output_cnt = 27, 7
        self.learning_rate = learning_rate
        
        
        raw_data = self.load_steal_data()
        self._kfold_data = self.kfold_data(raw_data)
        
        
    def model_trainning(self, train_data, test_data, proc_num=None, return_dict = None):
        model_init = steel_model(learning_rate=self.learning_rate)
        model_init.init_data(train_data = train_data,
                             test_data = test_data)
        model_init.model_compile()
        model_init.model_fit(verbose=0)
        model_result_dict = model_init.model_evaluate(verbose=0)
        
        if proc_num is not None and return_dict is not None:
            return_dict[proc_num] = model_result_dict

        return model_result_dict
        
    def model_train_multiprocess(self,):
        kfold_data_set = []
        for index in range(10):
            train_data = self.kfold_return_train(n_fold=index, kfold_data=self._kfold_data)
            test_data = self.kfold_return_test(n_fold=index, kfold_data=self._kfold_data)
            kfold_data_set.append((train_data, test_data))
            
        manager = Manager()
        return_dict = manager.dict()
        
        procs = []
        for index, (train_data, test_data) in enumerate(kfold_data_set):
            #print(train_data[0].shape, test_data[0].shape)
            proc = Process(target=self.model_trainning,
                           args=(train_data, test_data,
                                 index, return_dict),
                           name='{}-fold'.format(index)
                          )
            procs.append(proc)
            proc.start()
            
        for proc in procs:
            proc.join()
            
        return return_dict
    
    
    def kfold_model_evaluate_result(self,return_dict, verbose = 0):
        accuracies = []
        precisions = []
        recalls = []
        f1s = []
        losses = []
        
        for index in range(10):
            acc     = return_dict[index]['acc']
            loss    = return_dict[index]['loss']

            accuracies.append(acc)
            losses.append(loss)
            
        mean_acc    = np.array(accuracies).mean()
        mean_loss = np.array(losses).mean()
        
        return_result_list = [mean_acc, mean_loss]
        #print(return_result_list)
        if verbose is not 0:
            print("acc: {:2.4f}, loss: {:2.4f}".format(*return_result_list))
        

        return return_result_list
        
        
    
    def load_steal_data(self,):
        data, x, y = load_steal_dataset()
        return data
    
    def kfold_data(self, data):
        import sklearn
        from sklearn.model_selection import KFold
        kf = KFold(n_splits=10, shuffle=True)
        kf.get_n_splits(data)
        kfold_data = {}
        for index, (train_index, test_index) in enumerate(kf.split(data)):
            train_data = data[train_index]
            test_data = data[test_index]
            kfold_data[index] = {'train' : train_data, 'test' : test_data}
        return kfold_data

    def kfold_return_train(self, n_fold, kfold_data):
        output_cnt = self.output_cnt
        if n_fold not in range(10):
            print('{} is not in range(10)'.format(n_fold))
            raise NameError('Change n_fold')
        train_data = kfold_data[n_fold]['train']
        #test_data = kfold_data[n_fold]['test']
        train_data_input = train_data[:, :-output_cnt]
        train_data_output = train_data[:, -output_cnt:]
        return [train_data_input, train_data_output]
    
    def kfold_return_test(self, n_fold, kfold_data):
        output_cnt = self.output_cnt
        if n_fold not in range(10):
            print('{} is not in range(10)'.format(n_fold))
            raise NameError('Change n_fold')
        #train_data = kfold_data[n_fold]['train']
        test_data = kfold_data[n_fold]['test']
        test_data_input = test_data[:, :-output_cnt]
        test_data_output = test_data[:, -output_cnt:]
        return [test_data_input, test_data_output]

# %%
class steal_model_3_layer_optimize(steal_model_optimize):
    def __init__(self,HP=[None, None, None],learning_rate = 0.01):
        self.HP = HP
        super().__init__(learning_rate=learning_rate)
        
    def model_trainning(self, train_data, test_data, proc_num=None, return_dict = None):
        model_init = steel_model_3_layer(HP=self.HP, learning_rate=self.learning_rate)
        model_init.init_data(train_data = train_data,
                             test_data = test_data)
        model_init.model_compile()
        model_init.model_fit(verbose=0)
        model_result_dict = model_init.model_evaluate(verbose=0)
        
        if proc_num is not None and return_dict is not None:
            return_dict[proc_num] = model_result_dict

        return model_result_dict

# %%
class steal_model_4_layer_optimize(steal_model_optimize):
    def __init__(self,HP=[None, None, None, None],learning_rate = 0.01):
        self.HP = HP
        super().__init__(learning_rate=learning_rate)
        
    def model_trainning(self, train_data, test_data, proc_num=None, return_dict = None):
        model_init = steel_model_4_layer(HP=self.HP, learning_rate=self.learning_rate)
        model_init.init_data(train_data = train_data,
                             test_data = test_data)
        model_init.model_compile()
        model_init.model_fit(verbose=0)
        model_result_dict = model_init.model_evaluate(verbose=0)
        
        if proc_num is not None and return_dict is not None:
            return_dict[proc_num] = model_result_dict

        return model_result_dict

# %% [raw]
# kfold_trainning = steal_model_optimize()
# result_dict = kfold_trainning.model_train_multiprocess()
# result =  kfold_trainning.kfold_model_evaluate_result(result_dict, verbose=1)

# %%
kfold_trainning = steal_model_3_layer_optimize(HP=[20,20,10], learning_rate=0.001)
result_dict = kfold_trainning.model_train_multiprocess()
result =  kfold_trainning.kfold_model_evaluate_result(result_dict, verbose=1)
# Out:
# acc: 0.3467, loss: 1.8820

# %% [markdown]
# ## 3-layer optimization

# %%
hp_dict = {
    'layer_1' : 20,
    'layer_2' : 10,
    'layer_3' : 5,
    'learning_rate' : 0.001
}

default_HP = list(hp_dict.values())

def model_tunning(hp_list):
    HP_list2dict = {
        'layer_1' : hp_list[0],
        'layer_2' : hp_list[1],
        'layer_3' : hp_list[2],
        'LEARNING_RATE' : float(hp_list[3])
    }
    print("======================start trainning=======================")
    print(HP_list2dict.items())
    print('\n')
    
    tunning_model = steal_model_3_layer_optimize(HP=[hp_list[0], hp_list[1], hp_list[2]],
                                                 learning_rate = hp_list[3])
    result_dict = tunning_model.model_train_multiprocess()
    result = tunning_model.kfold_model_evaluate_result(result_dict, verbose=1)
    loss = result[-1]
    

    print('\n')
    print("======================end trainning=======================")
    return loss

#dim_RND_MEAN_nodes = Integer(low=-100, high=100, name='RND_MEAN')
#dim_RND_STD_nodes = Real(low=1e-8, high=1.0, prior='log-uniform', name='RND_STD')
dim_layer_1_unit = Integer(low=1, high=64, name='Layer_1')
dim_layer_2_unit = Integer(low=1, high=64, name='Layer_2')
dim_layer_3_unit = Integer(low=1, high=64, name='Layer_3')
dim_learning_rate_nodes = Real(low=1e-6, high=1.0, prior='log-uniform',name='LEARNING_RATE')

dimension_HP = [
                dim_layer_1_unit,
                dim_layer_2_unit,
                dim_layer_3_unit,
                dim_learning_rate_nodes
                ]



n_cell = 60
n_random_starts = 20

gp_fitting = gp_minimize(func=model_tunning,
                        dimensions=dimension_HP,
                        n_calls=n_cell,
                        n_random_starts=n_random_starts,
                        acq_func='EI',
                        x0=default_HP
                        )
# Out:
# ======================start trainning=======================
# dict_items([('layer_1', 20), ('layer_2', 10), ('layer_3', 5), ('LEARNING_RATE', 0.001)])
#
#
# acc: 0.3369, loss: 1.8712
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 20), ('layer_2', 39), ('layer_3', 53), ('LEARNING_RATE', 0.025487639748134765)])
#
#
# acc: 0.2183, loss: 50000.8397
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 64), ('layer_2', 13), ('layer_3', 6), ('LEARNING_RATE', 0.00014562027482509097)])
#
#
# acc: 0.2921, loss: 20001.5492
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 55), ('layer_2', 43), ('layer_3', 38), ('LEARNING_RATE', 0.016749934192692193)])
#
#
# acc: 0.1323, loss: 80000.3349
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 15), ('layer_2', 47), ('layer_3', 50), ('LEARNING_RATE', 2.1269910097970777e-05)])
#
#
# acc: 0.2911, loss: 272.5348
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 47), ('layer_2', 54), ('layer_3', 22), ('LEARNING_RATE', 1.0255523270873254e-06)])
#
#
# acc: 0.3581, loss: 12.9876
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 54), ('layer_2', 48), ('layer_3', 18), ('LEARNING_RATE', 0.0017176153692222453)])
#
#
# acc: 0.1690, loss: 70000.5371
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 31), ('layer_2', 44), ('layer_3', 32), ('LEARNING_RATE', 2.435162824973478e-05)])
#
#
# acc: 0.3148, loss: 10001.7490
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 10), ('layer_2', 10), ('layer_3', 4), ('LEARNING_RATE', 0.005346077279635138)])
#
#
# acc: 0.3467, loss: 1.7474
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 61), ('layer_2', 27), ('layer_3', 23), ('LEARNING_RATE', 3.0205699097354882e-05)])
#
#
# acc: 0.2814, loss: 20001.5819
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 39), ('layer_2', 18), ('layer_3', 7), ('LEARNING_RATE', 2.136612604489003e-06)])
#
#
# acc: 0.3137, loss: 1.9415
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 2), ('layer_2', 60), ('layer_3', 41), ('LEARNING_RATE', 0.4827552410006404)])
#
#
# acc: 0.3210, loss: 10001.5086
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 53), ('layer_2', 57), ('layer_3', 48), ('LEARNING_RATE', 2.282034477505856e-05)])
#
#
# acc: 0.2534, loss: 20001.9135
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 18), ('layer_2', 23), ('layer_3', 60), ('LEARNING_RATE', 0.07876033354194771)])
#
#
# acc: 0.1318, loss: 80000.3336
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 25), ('layer_2', 47), ('layer_3', 46), ('LEARNING_RATE', 9.65394261614435e-05)])
#
#
# acc: 0.3374, loss: 10001.7242
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 30), ('layer_2', 35), ('layer_3', 27), ('LEARNING_RATE', 3.3917430176007894e-05)])
#
#
# acc: 0.3359, loss: 1.9065
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 59), ('layer_2', 21), ('layer_3', 28), ('LEARNING_RATE', 1.1049298690177464e-05)])
#
#
# acc: 0.2900, loss: 20001.7076
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 45), ('layer_2', 55), ('layer_3', 53), ('LEARNING_RATE', 4.403202726419498e-05)])
#
#
# acc: 0.2349, loss: 40001.1581
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 41), ('layer_2', 49), ('layer_3', 8), ('LEARNING_RATE', 0.007700772077500258)])
#
#
# acc: 0.2926, loss: 20001.3816
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 64), ('layer_2', 15), ('layer_3', 35), ('LEARNING_RATE', 0.22250173395300668)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 61), ('layer_2', 63), ('layer_3', 17), ('LEARNING_RATE', 0.20548289723506968)])
#
#
# acc: 0.1077, loss: 90000.1643
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 26), ('layer_2', 9), ('layer_3', 30), ('LEARNING_RATE', 0.0010394383798094208)])
#
#
# acc: 0.2474, loss: 30001.3160
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 54), ('layer_2', 13), ('layer_3', 22), ('LEARNING_RATE', 0.00026747506314238025)])
#
#
# acc: 0.2710, loss: 30001.3490
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 31), ('layer_2', 1), ('layer_3', 46), ('LEARNING_RATE', 3.959191901114738e-06)])
#
#
# acc: 0.3473, loss: 1.9446
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 27), ('layer_2', 62), ('layer_3', 12), ('LEARNING_RATE', 0.002599225746092724)])
#
#
# acc: 0.2159, loss: 50000.9097
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 42), ('layer_2', 37), ('layer_3', 36), ('LEARNING_RATE', 0.015019666689612748)])
#
#
# acc: 0.1056, loss: 90000.1714
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 3), ('layer_2', 24), ('layer_3', 41), ('LEARNING_RATE', 0.4083258935531932)])
#
#
# acc: 0.3225, loss: 10001.5064
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 52), ('layer_2', 59), ('layer_3', 55), ('LEARNING_RATE', 0.0012303154176161045)])
#
#
# acc: 0.1870, loss: 60000.7509
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 57), ('layer_2', 7), ('layer_3', 61), ('LEARNING_RATE', 0.0009891712080487684)])
#
#
# acc: 0.2369, loss: 40001.1326
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 28), ('layer_2', 60), ('layer_3', 28), ('LEARNING_RATE', 0.001462036264978678)])
#
#
# acc: 0.2075, loss: 50000.9358
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 29), ('layer_2', 40), ('layer_3', 51), ('LEARNING_RATE', 0.20419577143511264)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 64), ('layer_2', 3), ('layer_3', 13), ('LEARNING_RATE', 0.004496734793234286)])
#
#
# acc: 0.3467, loss: 1.7690
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 60), ('layer_2', 47), ('layer_3', 21), ('LEARNING_RATE', 1.6824385707342554e-05)])
# acc: 0.3225, loss: 10001.7377
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 53), ('layer_2', 53), ('layer_3', 38), ('LEARNING_RATE', 2.914916312822439e-05)])
#
#
# acc: 0.2730, loss: 20001.5827
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 48), ('layer_2', 59), ('layer_3', 15), ('LEARNING_RATE', 1.3039999000102504e-06)])
#
#
# acc: 0.3488, loss: 2.3272
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 31), ('layer_2', 58), ('layer_3', 25), ('LEARNING_RATE', 0.5333299721880058)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 13), ('layer_2', 42), ('layer_3', 5), ('LEARNING_RATE', 5.586835420756017e-06)])
#
#
# acc: 0.3467, loss: 1.9455
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 24), ('layer_2', 5), ('layer_3', 42), ('LEARNING_RATE', 0.00281043747881641)])
#
#
# acc: 0.2653, loss: 30001.2587
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 18), ('layer_2', 53), ('layer_3', 47), ('LEARNING_RATE', 0.045301096316610646)])
#
#
# acc: 0.1031, loss: 90000.1696
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 27), ('layer_2', 39), ('layer_3', 35), ('LEARNING_RATE', 3.2108443347600465e-05)])
#
#
# acc: 0.3045, loss: 1.9323
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 10), ('layer_2', 28), ('layer_3', 13), ('LEARNING_RATE', 4.6055659261506565e-06)])
#
#
# acc: 0.3112, loss: 1.9362
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 4), ('layer_2', 55), ('layer_3', 60), ('LEARNING_RATE', 0.16126262832165533)])
#
#
# acc: 0.2122, loss: 50000.8398
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 20), ('layer_2', 5), ('layer_3', 18), ('LEARNING_RATE', 8.959480247384879e-05)])
#
#
# acc: 0.3147, loss: 1.9324
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 8), ('layer_2', 58), ('layer_3', 28), ('LEARNING_RATE', 0.012583488778721971)])
#
#
# acc: 0.3112, loss: 10001.5281
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 54), ('layer_2', 39), ('layer_3', 8), ('LEARNING_RATE', 3.0917966574680503e-06)])
#
#
# acc: 0.3467, loss: 1.9457
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 22), ('layer_2', 5), ('layer_3', 46), ('LEARNING_RATE', 0.0009010757419681325)])
#
#
# acc: 0.2988, loss: 10001.6814
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 23), ('layer_2', 24), ('layer_3', 58), ('LEARNING_RATE', 0.09018992179752078)])
#
#
# acc: 0.1623, loss: 70000.4998
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 39), ('layer_2', 28), ('layer_3', 41), ('LEARNING_RATE', 0.7525800778754695)])
#
#
# acc: 0.1081, loss: 90000.1700
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 55), ('layer_2', 10), ('layer_3', 54), ('LEARNING_RATE', 0.05224810060091932)])
#
#
# acc: 0.1371, loss: 80000.3390
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 18), ('layer_2', 23), ('layer_3', 9), ('LEARNING_RATE', 0.002497511455862538)])
#
#
# acc: 0.3257, loss: 10001.6399
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 50), ('layer_2', 31), ('layer_3', 23), ('LEARNING_RATE', 0.00014647728700334308)])
#
#
# acc: 0.2170, loss: 50000.9679
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 18), ('layer_2', 60), ('layer_3', 35), ('LEARNING_RATE', 1.9360303539504347e-05)])
#
#
# acc: 0.2591, loss: 10098.5012
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 14), ('layer_2', 20), ('layer_3', 55), ('LEARNING_RATE', 0.0065257886388636055)])
#
#
# acc: 0.1844, loss: 60000.6899
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 44), ('layer_2', 39), ('layer_3', 22), ('LEARNING_RATE', 0.00029478673358259794)])
#
#
# acc: 0.2324, loss: 40001.1505
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 63), ('layer_2', 13), ('layer_3', 34), ('LEARNING_RATE', 0.0289269369635121)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 44), ('layer_2', 28), ('layer_3', 46), ('LEARNING_RATE', 0.00012077641024844228)])
#
#
# acc: 0.2247, loss: 40001.1558
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 63), ('layer_2', 16), ('layer_3', 20), ('LEARNING_RATE', 0.2824611674111142)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 37), ('layer_2', 42), ('layer_3', 33), ('LEARNING_RATE', 0.0029981876604613907)])
#
#
# acc: 0.1623, loss: 70000.5410
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 4), ('layer_2', 60), ('layer_3', 35), ('LEARNING_RATE', 0.21524490646486394)])
#
#
# acc: 0.2792, loss: 30001.1584
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 54), ('layer_2', 16), ('layer_3', 58), ('LEARNING_RATE', 0.0008369702051910219)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================

# %%
opt_lr = gp_fitting.x
opt_lr
# Out:
# [10, 10, 4, 0.005346077279635138]

# %%
kfold_trainning_opt = steal_model_3_layer_optimize(HP=opt_lr[:-1],learning_rate=opt_lr[-1])
result_dict = kfold_trainning_opt.model_train_multiprocess()
result =  kfold_trainning_opt.kfold_model_evaluate_result(result_dict, verbose=1)
# Out:
# acc: 0.3468, loss: 1.7538

# %%
kfold_trainning_ref = steal_model_3_layer_optimize(HP=[12,6,4], learning_rate=0.0001)
result_dict = kfold_trainning_ref.model_train_multiprocess()
result =  kfold_trainning_ref.kfold_model_evaluate_result(result_dict, verbose=1)
# Out:
# acc: 0.3415, loss: 1.9352

# %%
_ = plot_evaluations(gp_fitting)

# %%
_ = plot_objective(gp_fitting)

# %% [markdown]
# ## 4 layer optimization

# %%
hp_dict = {
    'layer_1' : 20,
    'layer_2' : 10,
    'layer_3' : 5,
    'layer_4' : 5,
    'learning_rate' : 0.001
}

default_HP = list(hp_dict.values())

def model_tunning(hp_list):
    HP_list2dict = {
        'layer_1' : hp_list[0],
        'layer_2' : hp_list[1],
        'layer_3' : hp_list[2],
        'layer_4' : hp_list[3],
        'LEARNING_RATE' : float(hp_list[4])
    }
    print("======================start trainning=======================")
    print(HP_list2dict.items())
    print('\n')
    
    tunning_model = steal_model_3_layer_optimize(HP=hp_list[:-1],learning_rate = hp_list[-1])
    result_dict = tunning_model.model_train_multiprocess()
    result = tunning_model.kfold_model_evaluate_result(result_dict, verbose=1)
    loss = result[-1]
    

    print('\n')
    print("======================end trainning=======================")
    return loss

#dim_RND_MEAN_nodes = Integer(low=-100, high=100, name='RND_MEAN')
#dim_RND_STD_nodes = Real(low=1e-8, high=1.0, prior='log-uniform', name='RND_STD')
dim_layer_1_unit = Integer(low=1, high=64, name='Layer_1')
dim_layer_2_unit = Integer(low=1, high=64, name='Layer_2')
dim_layer_3_unit = Integer(low=1, high=64, name='Layer_3')
dim_layer_4_unit = Integer(low=1, high=64, name='Layer_4')
dim_learning_rate_nodes = Real(low=1e-6, high=1.0, prior='log-uniform',name='LEARNING_RATE')

dimension_HP = [
                dim_layer_1_unit,
                dim_layer_2_unit,
                dim_layer_3_unit,
                dim_layer_4_unit,
                dim_learning_rate_nodes
                ]



n_cell = 60
n_random_starts = 20

gp_fitting_4 = gp_minimize(func=model_tunning,
                        dimensions=dimension_HP,
                        n_calls=n_cell,
                        n_random_starts=n_random_starts,
                        acq_func='EI',
                        x0=default_HP
                        )
# Out:
# ======================start trainning=======================
# dict_items([('layer_1', 20), ('layer_2', 10), ('layer_3', 5), ('layer_4', 5), ('LEARNING_RATE', 0.001)])
#
#
# acc: 0.3235, loss: 10001.6982
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 4), ('layer_2', 20), ('layer_3', 8), ('layer_4', 42), ('LEARNING_RATE', 8.933333232869667e-06)])
#
#
# acc: 0.3473, loss: 1.9458
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 48), ('layer_2', 46), ('layer_3', 34), ('layer_4', 64), ('LEARNING_RATE', 0.004362719518519178)])
#
#
# acc: 0.2112, loss: 50000.8891
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 1), ('layer_2', 41), ('layer_3', 26), ('layer_4', 45), ('LEARNING_RATE', 0.04070216655895629)])
#
#
# acc: 0.3468, loss: 1.6746
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 56), ('layer_2', 44), ('layer_3', 63), ('layer_4', 13), ('LEARNING_RATE', 0.00044146482295049977)])
#
#
# acc: 0.1613, loss: 70000.5703
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 56), ('layer_2', 33), ('layer_3', 43), ('layer_4', 16), ('LEARNING_RATE', 0.00010380832108111647)])
#
#
# acc: 0.2828, loss: 20001.5194
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 25), ('layer_2', 38), ('layer_3', 63), ('layer_4', 41), ('LEARNING_RATE', 0.00010133111651638493)])
#
#
# acc: 0.2653, loss: 30001.3093
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 61), ('layer_2', 38), ('layer_3', 7), ('layer_4', 40), ('LEARNING_RATE', 1.770615737033712e-05)])
#
#
# acc: 0.3468, loss: 1.9447
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 60), ('layer_2', 62), ('layer_3', 38), ('layer_4', 48), ('LEARNING_RATE', 0.0028986508566784144)])
#
#
# acc: 0.2149, loss: 50000.8919
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 4), ('layer_2', 18), ('layer_3', 14), ('layer_4', 27), ('LEARNING_RATE', 0.1304703591589477)])
#
#
# acc: 0.3137, loss: 10001.5076
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 25), ('layer_2', 31), ('layer_3', 3), ('layer_4', 42), ('LEARNING_RATE', 0.00031160511536442164)])
#
#
# acc: 0.3467, loss: 1.9260
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 63), ('layer_2', 51), ('layer_3', 39), ('layer_4', 8), ('LEARNING_RATE', 2.303579097125049e-06)])
#
#
# acc: 0.2941, loss: 10038.0048
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 15), ('layer_2', 51), ('layer_3', 52), ('layer_4', 50), ('LEARNING_RATE', 0.8833368438977398)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 27), ('layer_2', 19), ('layer_3', 56), ('layer_4', 44), ('LEARNING_RATE', 0.000764610687902182)])
#
#
# acc: 0.2864, loss: 10001.7057
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 23), ('layer_2', 62), ('layer_3', 55), ('layer_4', 43), ('LEARNING_RATE', 0.6113447660720297)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 3), ('layer_2', 35), ('layer_3', 50), ('layer_4', 12), ('LEARNING_RATE', 0.0033255198011362614)])
#
#
# acc: 0.3467, loss: 1.7841
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 14), ('layer_2', 51), ('layer_3', 11), ('layer_4', 15), ('LEARNING_RATE', 0.04850682954482334)])
#
#
# acc: 0.2989, loss: 20001.3328
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 44), ('layer_2', 25), ('layer_3', 6), ('layer_4', 46), ('LEARNING_RATE', 0.10689770694482859)])
#
#
# acc: 0.1756, loss: 60000.6792
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 46), ('layer_2', 39), ('layer_3', 12), ('layer_4', 3), ('LEARNING_RATE', 0.4655695385612873)])
#
#
# acc: 0.1974, loss: 60000.6635
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 35), ('layer_2', 12), ('layer_3', 62), ('layer_4', 41), ('LEARNING_RATE', 0.0018228645690627143)])
#
#
# acc: 0.2019, loss: 50000.9221
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 46), ('layer_2', 49), ('layer_3', 46), ('layer_4', 52), ('LEARNING_RATE', 6.633034329286296e-05)])
#
#
# acc: 0.1639, loss: 50001.0293
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 51), ('layer_2', 55), ('layer_3', 6), ('layer_4', 9), ('LEARNING_RATE', 0.056074820538328324)])
#
#
# acc: 0.2931, loss: 20001.3377
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 44), ('layer_2', 35), ('layer_3', 43), ('layer_4', 34), ('LEARNING_RATE', 0.00046911974659012473)])
#
#
# acc: 0.1627, loss: 60000.7643
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 39), ('layer_2', 14), ('layer_3', 36), ('layer_4', 32), ('LEARNING_RATE', 9.538999975103333e-06)])
#
#
# acc: 0.2252, loss: 30001.4865
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 14), ('layer_2', 49), ('layer_3', 24), ('layer_4', 50), ('LEARNING_RATE', 1.9319056029858755e-06)])
#
#
# acc: 0.3581, loss: 21.2490
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 60), ('layer_2', 60), ('layer_3', 58), ('layer_4', 18), ('LEARNING_RATE', 1.4191183775591269e-05)])
#
#
# acc: 0.2323, loss: 40001.1534
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 45), ('layer_2', 37), ('layer_3', 54), ('layer_4', 49), ('LEARNING_RATE', 0.0196947515393697)])
#
#
# acc: 0.2170, loss: 50000.8376
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 24), ('layer_2', 27), ('layer_3', 9), ('layer_4', 36), ('LEARNING_RATE', 0.7593517330131876)])
#
#
# acc: 0.1670, loss: 70000.5031
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 32), ('layer_2', 32), ('layer_3', 59), ('layer_4', 26), ('LEARNING_RATE', 5.854114852850107e-05)])
#
#
# acc: 0.2876, loss: 20001.5253
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 11), ('layer_2', 23), ('layer_3', 40), ('layer_4', 33), ('LEARNING_RATE', 3.648067548845458e-05)])
#
#
# acc: 0.2751, loss: 10001.7166
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 17), ('layer_2', 2), ('layer_3', 22), ('layer_4', 24), ('LEARNING_RATE', 0.028328850372079974)])
# acc: 0.3204, loss: 10001.5110
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 12), ('layer_2', 60), ('layer_3', 9), ('layer_4', 58), ('LEARNING_RATE', 0.003694044081453206)])
#
#
# acc: 0.3041, loss: 20001.4180
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 48), ('layer_2', 9), ('layer_3', 51), ('layer_4', 44), ('LEARNING_RATE', 0.004061208223705949)])
#
#
# acc: 0.2091, loss: 50000.8920
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 42), ('layer_2', 24), ('layer_3', 38), ('layer_4', 59), ('LEARNING_RATE', 0.0006620070833478525)])
#
#
# acc: 0.2777, loss: 30001.3328
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 46), ('layer_2', 7), ('layer_3', 33), ('layer_4', 48), ('LEARNING_RATE', 0.3735669438848551)])
#
#
# acc: 0.1680, loss: 70000.5008
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 21), ('layer_2', 25), ('layer_3', 34), ('layer_4', 37), ('LEARNING_RATE', 0.5131175991614568)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 53), ('layer_2', 25), ('layer_3', 37), ('layer_4', 24), ('LEARNING_RATE', 2.2779924285794643e-05)])
#
#
# acc: 0.2412, loss: 40001.1558
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 60), ('layer_2', 42), ('layer_3', 41), ('layer_4', 64), ('LEARNING_RATE', 0.0001872098237702468)])
#
#
# acc: 0.1845, loss: 60000.7761
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 63), ('layer_2', 58), ('layer_3', 41), ('layer_4', 31), ('LEARNING_RATE', 0.0006147769964948975)])
#
#
# acc: 0.1895, loss: 60000.7567
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 62), ('layer_2', 33), ('layer_3', 50), ('layer_4', 9), ('LEARNING_RATE', 0.04431071040073596)])
#
#
# acc: 0.0814, loss: 100000.0000
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 10), ('layer_2', 46), ('layer_3', 33), ('layer_4', 58), ('LEARNING_RATE', 0.043509912654413015)])
#
#
# acc: 0.2405, loss: 40001.0131
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 61), ('layer_2', 22), ('layer_3', 57), ('layer_4', 52), ('LEARNING_RATE', 0.004056116957371367)])
#
#
# acc: 0.1963, loss: 70000.5278
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 34), ('layer_2', 22), ('layer_3', 43), ('layer_4', 8), ('LEARNING_RATE', 0.0013841582539894128)])
#
#
# acc: 0.1844, loss: 60000.7488
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 31), ('layer_2', 59), ('layer_3', 8), ('layer_4', 43), ('LEARNING_RATE', 0.036069728232722253)])
#
#
# acc: 0.2653, loss: 30001.1745
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 13), ('layer_2', 33), ('layer_3', 7), ('layer_4', 33), ('LEARNING_RATE', 0.9141389711265338)])
#
#
# acc: 0.2921, loss: 20001.3444
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 22), ('layer_2', 2), ('layer_3', 8), ('layer_4', 42), ('LEARNING_RATE', 0.0001360118464260856)])
#
#
# acc: 0.3247, loss: 1.9229
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 26), ('layer_2', 19), ('layer_3', 24), ('layer_4', 46), ('LEARNING_RATE', 0.0015876438962448213)])
#
#
# acc: 0.2170, loss: 50000.9279
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 43), ('layer_2', 4), ('layer_3', 4), ('layer_4', 8), ('LEARNING_RATE', 1.571520049994612e-05)])
#
#
# acc: 0.3390, loss: 1.9438
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 46), ('layer_2', 54), ('layer_3', 41), ('layer_4', 54), ('LEARNING_RATE', 0.02403769183567103)])
#
#
# acc: 0.1376, loss: 80000.3383
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 59), ('layer_2', 33), ('layer_3', 53), ('layer_4', 58), ('LEARNING_RATE', 0.015965111575317634)])
#
#
# acc: 0.1077, loss: 90000.1707
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 18), ('layer_2', 47), ('layer_3', 53), ('layer_4', 15), ('LEARNING_RATE', 0.0053916454967235595)])
#
#
# acc: 0.2101, loss: 50000.8764
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 26), ('layer_2', 56), ('layer_3', 22), ('layer_4', 46), ('LEARNING_RATE', 0.0034004393351353994)])
#
#
# acc: 0.2149, loss: 50000.8880
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 62), ('layer_2', 5), ('layer_3', 57), ('layer_4', 58), ('LEARNING_RATE', 0.009426099140087582)])
#
#
# acc: 0.2988, loss: 20001.3651
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 8), ('layer_2', 50), ('layer_3', 52), ('layer_4', 32), ('LEARNING_RATE', 5.5502493982165665e-06)])
#
#
# acc: 0.3251, loss: 1.9208
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 46), ('layer_2', 3), ('layer_3', 12), ('layer_4', 62), ('LEARNING_RATE', 0.014158300063722077)])
#
#
# acc: 0.3194, loss: 10001.5259
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 44), ('layer_2', 38), ('layer_3', 55), ('layer_4', 10), ('LEARNING_RATE', 0.0021499648906269323)])
#
#
# acc: 0.1407, loss: 80000.3654
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 53), ('layer_2', 46), ('layer_3', 40), ('layer_4', 5), ('LEARNING_RATE', 0.012210405049996346)])
#
#
# acc: 0.1385, loss: 80000.3335
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 38), ('layer_2', 18), ('layer_3', 5), ('layer_4', 22), ('LEARNING_RATE', 0.00037418126430768534)])
#
#
# acc: 0.3379, loss: 1.9087
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 57), ('layer_2', 45), ('layer_3', 6), ('layer_4', 40), ('LEARNING_RATE', 1.801666040930767e-05)])
#
#
# acc: 0.3467, loss: 1.9447
#
#
# ======================end trainning=======================
# ======================start trainning=======================
# dict_items([('layer_1', 47), ('layer_2', 46), ('layer_3', 29), ('layer_4', 18), ('LEARNING_RATE', 2.440182819892768e-06)])
#
#
# acc: 0.3271, loss: 22.8261
#
#
# ======================end trainning=======================

# %%
opt_lr = gp_fitting_4.x
opt_lr
# Out:
# [1, 41, 26, 45, 0.04070216655895629]

# %%
kfold_trainning_opt = steal_model_4_layer_optimize(HP=opt_lr[:-1],learning_rate=opt_lr[-1])
result_dict = kfold_trainning_opt.model_train_multiprocess()
result =  kfold_trainning_opt.kfold_model_evaluate_result(result_dict, verbose=1)
# Out:
# acc: 0.3467, loss: 1.6750

# %%
_ = plot_evaluations(gp_fitting_4)

# %%
_ = plot_objective(gp_fitting_4)
